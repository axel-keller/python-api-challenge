# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1721'>
#   <div id="c65b5505-ae0c-4a1a-87c1-2471b878b647" data-root-id="p1721" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0  san ignacio de velasco -16.3667  -60.9500     37.42        29
# 1        1                   lihue  21.9789 -159.3672     23.77        95
# 2        2       port-aux-francais -49.3500   70.2167      2.20        85
# 3        3              georgetown   5.4112  100.3354     27.96        83
# 4        4              codrington -38.2667  141.9667      8.34        71
#
#    Cloudiness  Wind Speed Country        Date
# 0          50        6.57      BO  1729790271
# 1          75        1.54      US  1729790271
# 2         100        8.36      TF  1729790271
# 3          20        1.03      MY  1729790271
# 4          51        5.24      AU  1729790271

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_df.hvplot.points(x='Lng', y='Lat', geo=True, tiles='OSM', 
                           size='Humidity', color='blue', alpha=0.6,
                           title="City Locations with Point Size Representing Humidity")
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
city_data_df = city_data_df[
    (city_data_df['Max Temp'] < 30) &
    (city_data_df['Max Temp'] > 20) &
    (city_data_df['Wind Speed'] < 8.0) &
    (city_data_df['Cloudiness'] == 0)
]
# Display sample data
city_data_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 40        40       fort irwin  35.2627 -116.6848     22.74        17
# 75        75            kousa  25.9141   32.7636     25.94        15
# 93        93            pisco -13.7000  -76.2167     21.12        77
# 106      106          safford  32.8340 -109.7076     24.51        20
# 151      151           ormara  25.2088   64.6357     28.13        75
# 157      157        dickinson  29.4608  -95.0513     28.93        64
# 165      165            aswan  24.0934   32.9070     26.38        16
# 169      169       thaba nchu -29.2093   26.8390     21.89        25
# 181      181        tucumcari  35.1717 -103.7250     22.91        31
# 202      202       siler city  35.7235  -79.4622     23.89        29
# 244      244           ghanzi -21.5667   21.7833     29.54         7
# 263      263         holualoa  19.6228 -155.9522     22.15        85
# 276      276           dakhla  23.6848  -15.9580     26.01        41
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty "Hotel Name" column
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 40        fort irwin      US  35.2627 -116.6848        17
# 75             kousa      EG  25.9141   32.7636        15
# 93             pisco      PE -13.7000  -76.2167        77
# 106          safford      US  32.8340 -109.7076        20
# 151           ormara      PK  25.2088   64.6357        75
# 157        dickinson      US  29.4608  -95.0513        64
# 165            aswan      EG  24.0934   32.9070        16
# 169       thaba nchu      ZA -29.2093   26.8390        25
# 181        tucumcari      US  35.1717 -103.7250        31
# 202       siler city      US  35.7235  -79.4622        29
# 244           ghanzi      BW -21.5667   21.7833         7
# 263         holualoa      US  19.6228 -155.9522        85
# 276           dakhla      EH  23.6848  -15.9580        41
# 283       greenville      US  35.6127  -77.3663        47
# 310             idfu      EG  24.9803   32.8747        15
# ...

# %% [markdown]
# Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
hotel_df

# Set search radius in meters
radius = 10000  # 10,000 meters (10 km)

# Set up static parameters for the Geoapify API
params = {
    "categories": "accommodation.hotel",
    "limit": 1,  # Limit the result to the nearest hotel
    "apiKey": geoapify_key  # Use the imported API key
}

# Print a message to follow up on the hotel search
print("Starting hotel search")

# Iterate only through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from hotel_df
    lat = row['Lat']
    lng = row['Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found"
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

    # Pause to avoid exceeding rate limits
    time.sleep(1)

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# fort irwin - nearest hotel: Landmark Inn
# kousa - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# safford - nearest hotel: Quality Inn And Suites
# ormara - nearest hotel: No hotel found
# dickinson - nearest hotel: Days Inn by Wyndham Dickinson TX
# aswan - nearest hotel: Oscar Hotel
# thaba nchu - nearest hotel: No hotel found
# tucumcari - nearest hotel: Pow Wow Inn
# siler city - nearest hotel: Days Inn & Suites by Wyndham Siler City
# ghanzi - nearest hotel: Ghanzi farmhouse
# holualoa - nearest hotel: Kona Hotel
# dakhla - nearest hotel: Hotel Ayouz
# greenville - nearest hotel: Quality Inn
# idfu - nearest hotel: Hotel Diamond also known as Massa
# rehoboth - nearest hotel: Suidwes Hotel
# college station - nearest hotel: La Quinta Inn
# tan-tan - nearest hotel: Sable d´or
# fort bragg - nearest hotel: Airborne Inn Lodging
# nanakuli - nearest hotel: Aulani, A Disney Resort & Spa
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

hotel_df

# Create an interactive map with hover details
map_plot = hotel_df.hvplot.points(
    x='Lng', 
    y='Lat', 
    geo=True, 
    tiles='OSM', 
    size='Humidity', 
    color='blue', 
    alpha=0.6, 
    title="City Locations with Hotels",
    hover_cols=['City', 'Country', 'Hotel Name'],
    xlim=(-80, 180),  # Set longitude limits to cover the entire globe
    ylim=(-90, 90),     # Set latitude limits to cover the entire globe
    width=900,         # Set the width of the plot
    height=500         # Set the height of the plot
)

# Show the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
